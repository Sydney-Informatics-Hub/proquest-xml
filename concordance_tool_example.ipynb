# %%
import pandas as pd
import numpy as np
import glob
import nltk

from proquest_xml import ProquestXml, create_dataframe, filter_company_reports, enter_query, concordance_dataframe

# %% [markdown]
# ### Read in XML corpora and create a dictionary

# %%
filenames = glob.glob('path/to/file/*.xml')

docs = {doc.id: doc for doc in 
        (ProquestXml(f) for f in filenames)}

# %% [markdown]
# ### Filter out 'Company Data Report' XML files

# %%
docs = filter_company_reports(docs)

# %% [markdown]
# ### Create dataframe from filtered dictionary

# %%
df = create_dataframe(docs.values())
df.head(5)
# Out:
#            id                                              title  \
# 0  2390914166  Osceola anuncia plan de recuperación, nuevo si...
# 1  2390939976  Virtual GRADUCon discussions examine impact of...
# 2  2390931455  Se posterga Asamblea General del Patronato de ...
# 3  2390919681  Cierran por tercer día consecutivo primer cuad...
# 4  2390914548  Andhra govt politicising COVID-19 situation : ...
#
#   date_published               publication author1_last_name  \
# 0     2020-04-17         TCA Regional News             Cotto
# 1     2020-04-16           University Wire            Tessel
# 2     2020-04-17                   NOTIMEX              None
# 3     2020-04-17                   NOTIMEX              None
# 4     2020-04-18  Asian News International              None
#
#   author1_first_name author1_full_name other_authors article_type  \
# 0             Ingrid      Ingrid Cotto            []         News
# 1            Michael    Michael Tessel            []         News
# 2               None              None            []         News
# 3               None              None            []         News
# 4               None              None            []         News
#
#                                                 text
# 0  \nApril 17--El gobierno de Osceola intenta vol...
# 1  \nPublication: The Pulse, , Finch University o...
# 2  \nPor Guillermo Abogado González\n\nMéxico, 17...
# 3  \nPlaya del Carmen, 17 Abr (Notimex).- La Secr...
# 4  \n\nHyderabad (Telangana) [India], April 18 (A...

# %% [markdown]
# ### Concordance tool
#
# There are two steps for creating a concordance of the corpus above.
#
# 1. Specify a list of words to query the text of the corpus using enter_query(). When prompted, enter a list of words separated by commas, e.g. rights,liberties,freedoms. The function also accepts strings made up of multiple words, which must be separated by spaces, e.g. rights,human rights,bill of rights,liberties. Click "enter" when satisfied with the list of words to have Python store the words as a list.
#
# 2. Apply the list of words to the corpus to generate a dataframe containing the query and the surrounding words.

# %%
# Create a list of words

word_list = enter_query()
# Out:
# Please enter the words you wish to query separated by commas (e.g. rights,freedoms,liberties). If you wish to query multiple words at the same time, separate them using a space (e.g. freedoms,human rights,liberties)rights,human rights,freedom,freedoms,liberties

# %%
# Check that the list has been correctly generated

word_list
# Out:
# ['rights', 'human rights', 'freedom', 'freedoms', 'liberties']

# %%
# Query the dataframe of the XML corpus with the list

dataframe = concordance_dataframe(df, word_list)

# %%
dataframe
# Out:
#              id                                              title  \
# 20   2390914548  Andhra govt politicising COVID-19 situation : ...
# 90   2390914605              AllianceBernstein Holding climbs 4.8%
# 95   2390914188  In regular touch with centre, states to bring ...
# 190  2390914102  Combating COVID-19: Laboratories should speed ...
# 225  2390914275  Champagne, Ukraine reject Iran crash report su...
# 226  2390914275  Champagne, Ukraine reject Iran crash report su...
# 241  2390914075   Arbor Realty Trust soars 11.7% on average volume
# 251  2390914060          Ashland Global Holdings up 6.2% in 2 days
# 281  2390914737      Brazil's coronavirus death toll surpass 2,000
# 301  2390914681              Annaly Capital Management climbs 5.5%
# 302  2390914681              Annaly Capital Management climbs 5.5%
# 492  2390914630     Belden inches higher, resistance at 12-day EMA
#
#     date_published               publication author1_last_name  \
# 20      2020-04-18  Asian News International              None
# 90      2020-04-17      News Bites US - NYSE              None
# 95      2020-04-18  Asian News International              None
# 190     2020-04-18  Asian News International              None
# 225     2020-04-16    National Post (Online)              None
# 226     2020-04-16    National Post (Online)              None
# 241     2020-04-17      News Bites US - NYSE              None
# 251     2020-04-17      News Bites US - NYSE              None
# 281     2020-04-18  Asian News International              None
# 301     2020-04-17      News Bites US - NYSE              None
# 302     2020-04-17      News Bites US - NYSE              None
# 492     2020-04-17      News Bites US - NYSE              None
#
#     author1_first_name other_authors article_type  \
# 20                None            []         News
# 90                None            []         News
# 95                None            []         News
# 190               None            []         News
# 225               None            []         News
# 226               None            []         News
# 241               None            []         News
# 251               None            []         News
# 281               None            []         News
# 301               None            []         News
# 302               None            []         News
# 492               None            []         News
#
#                                                   left   query  \
# 20   irregularities in the distribution of grocerie...  rights
# 90   to read in the press an inaccurate and unfound...  rights
# 95   from 4,000 tests per day to 10,000 tests per d...  rights
# 190  Pradesh , including 74 cured and discharged an...  rights
# 225  to sign a memorandum of understanding in which...  rights
# 226  that Canada , Ukraine or any of the other coun...  rights
# 241  compared to $ 14.2 million and 1.54 % for the ...  rights
# 251  Tender Offers may no longer be withdrawn , exc...  rights
# 281  distancing , resulting in his removal from off...  rights
# 301  . On the Redemption Date , dividends on the Se...  rights
# 302  . On the Redemption Date , dividends on the Se...  rights
# 492  of $ 100,000 to Contact the Firm LOS ANGELES -...  rights
#
#                                                  right
# 20   reserved . Provided by SyndiGate Media Inc. ( ...
# 90   of the Company and its management , despite th...
# 95   reserved . Provided by SyndiGate Media Inc. ( ...
# 190  reserved . Provided by SyndiGate Media Inc. ( ...
# 225  for legal compensation . Iran 's Revolutionary...
# 226  to hold Iran to account . `` That would not be...
# 241  was $ 29.9 million for the quarter , reflectin...
# 251  are required by law . January 22 : Ashland ann...
# 281  reserved . Provided by SyndiGate Media Inc. ( ...
# 301  relating to the Series C Preferred Stock will ...
# 302  relating to the Series H Preferred Stock will ...
# 492  litigation firm , announces that it is investi...

# %% [markdown]
# ### Export dataframe to Excel file

# %%
dataframe.to_excel("your_file_name.xlsx")
